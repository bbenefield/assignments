# %% [markdown]
# # Lab One: Visualization and Data Preprocessing
# ### Ryan Bass, Brett Benefield, Cho Kim, Nicole Wittlin

# %% [markdown]
# # <span style="color:red">Resubmission Summary</span>
#
# ## <span style="color:red">Simple Statistics</span>
# - <span style="color:red">Write up of Simple Statistics about College Enrollment Data</span>
# - <span style="color:red">Write up of Simple Statistics about Personnel Data</span>
#
# ## <span style="color:red">Visualize Attributes</span>
# - <span style="color:red">Bar graph of College Enrollment Percentages by District (LEA)</span>
# - <span style="color:red">Box Plot of College Enrollment Percentages by School and District</span>
# - <span style="color:red">Box Plot of Teacher Attributes</span>
# - <span style="color:red">Box Plot of Teacher Attributes with less than 65% Licensed</span>
# - <span style="color:red">Box Plot of Teacher Attributes with more than 32% 1st Year Turnover</span>
#
# ## <span style="color:red">Explore Attributes and Class</span>
#
# - <span style="color:red">Individual scatter plots of the % students who enrolled in college versus: % licensed teachers, average number of teachers per school, number of National Board Certified Staff, the % one year teacher turnover, % of teachers with 11+ years of experience, and % of teachers with 0-3 years of experience, and % one year turnover of teachers.
# - <span style="color:red">Individual box plots of the quartiles of % students who enrolled in college versus: % licensed teachers, average number of teachers per school, number of National Board Certified Staff, the % one year teacher turnover, % of teachers with 11+ years of experience, % of teachers with 0-3 years of experience, and % one year turnover of teachers.
#
# ## <span style="color:red">New Features</span>
# - <span style="color: red">Added information about new features we could consider

# %% [markdown]
# # Business Understanding

# %% [markdown]
# The team selected data from the Belk Endowment Educational Attainment Data for North Carolina Public Schools, which contains the North Carolina Public Schools Report Card as well as the Statistical Profiles Databases. This data was compiled by Dr. Jake Drew from original sources provided by the Public Schools of North Carolina (http://ncpublicschools.org), and the compilation, research, and analysis of the educational attainment data was funded by the John M. Belk Endowment (JMBE).
#
# JMBE’s mission is focused on postsecondary education in North Carolina to help underrepresented students access and complete postsecondary education and be better prepared for entering the workforce. The educational attainment data set contains comprehensive statistics, demographics, and achievement metrics about North Carolina public, charter, and alternative elementary, middle, and high schools. This wealth of data is the foundation for research to help JMBE understand trends and improve postsecondary pathways in the state.
#
# Our team has selected a subset from the larger educational attainment data to explore the relationship between enrollment in postsecondary education within 16 months of high school graduation and teacher metrics related to teacher education, licensing, and certification, in addition to years of experience. This is important to help identify both positive and negative factors influencing students’ enrollment decisions and understand how educators can impact the pipeline to higher education.
#
# Our efforts will include a model that will attempt to identify key attributes that will increase or decrease the percentage of students enrolled in a postsecondary education. The effectiveness of the model will be measured by how accurately our model performs against a test set of data. Our goal is to build a model that can predit the percentage of students who enrolled in postsecondary education within 25% of the real value.

# %% [markdown]
# # Data Meaning Type

# %% [markdown]
# We used the <a href="https://github.com/jakemdrew/EducationDataNC/blob/master/2017/Raw%20Datasets/college-enrollment.csv">College Enrollment data set</a> and the <a href="https://github.com/jakemdrew/EducationDataNC/blob/master/2017/Raw%20Datasets/personnel.csv">Personnel data set</a> available in the <a href="https://github.com/jakemdrew/EducationDataNC">EducationDataNC</a> repository published by Dr. Drew.
#
# #### College Enrollment data set
# The college enrollment data set we examined has 12,827 rows of data, with 13 attributes. The data set contains counts and percentages of postsecondary enrollment action as defined by the US Department of Education C160 EDEN (Education Data Exchange Network) for students who graduated in 2015. The data has subgroups of counts and percentages by school, district, and the state. A status of ENROLL means the count or percentage enrolled in an institution of higher education (IHE) within 16 months of receiving a regular high school diploma, and NOENROLL means the count or percentage of students who did not enroll in an IHE within 16 months of receiving a high school diploma.
#
# The description of the attributes below can be found in the <a href="http://www.ncpublicschools.org/docs/src/researchers/data-dictionary.pdf">data dictionary</a> published by the NC Public Schools.

# %% [markdown]
# | Attribute | Description | Type | % missing (in %) |
# |----------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------|------------------|
# | Graduation_year | Year students graduated from high school | Nominal | 0 |
# | Unit_code | Code to identify school/LEA/State<br> Unit codes belonging to individual schools may be mapped to a given district using the first 3 characters of the unit code. For example, schools belonging to the district "995LEA" will each have unit code that begins with 995. | Nominal | 0 |
# | leaname | LEA (Local Education Agency) Name <br> LEA is a commonly used acronym for a school district | Nominal | .2 |
# | schname | School Name | Nominal | 19.4 |
# | status | The postsecondary enrollment action as defined in the US Department of Education C160 EDEN (Education Data Exchange Network) specification <br>  <table><tr><td>Enroll</td><td>Enrolled in an IHE within 16 months of receiving a regular high school diploma</td></tr> <tr><td>NOENROLL</td><td>Did not enroll in an IHE within 16 months of receiving a regular high school diploma</td></tr> </table> | Nominal | 0 |
# | subgroup | A subset of the total population that shares a common characteristic, like sex or race <br> INSERT HTML TABLE HERE | Nominal | 0 |
# | Subgroup_name | Full description of the subgroup | Nominal | 0 |
# | schcount | Count of students by subgroup and status (ENROLL, NOENROLL) within a school with masking applied | Continuous | 42.5 |
# | leacount | Count of students by subgroup and status (ENROLL, NOENROLL) within a LEA/Charter with masking applied | Continuous | 12.9 |
# | seacount | Count of students by subgroup and status (ENROLL, NOENROLL) within the State (SEA - State Educational Agency) | Continuous | 0 |
# | sch_percent_enrolled | The percentage of enrolled students among total students (ENROLL Count/ TOTAL Count) within a school with masking applied | Ordinal | 75.1 |
# | lea_percent_enrolled | The percentage of enrolled students among total students (ENROLL Count/ TOTAL Count) within a LEA/Charter with masking applied | Ordinal | 71.5 |
# | sea_percent_enrolled | The percentage of enrolled students among total students (ENROLL Count/ TOTAL Count) within the State (SEA)\ | Ordinal | 70.8 |

# %% [markdown]
# #### College Enrollment Table Summary
#
# The schcount is the count of students within a school that enrolled or did not enroll in an institute of higher education within 16 months of receiving their high school diploma. The values range from 5 to 423 in the data set.
#
# The leacount is the count of students within a LEA or Charter by subgroup and status. The values range from 5 to 5844 in the data set.
#
# The seacount is the count of students within the state by subgroup and status. The values range from 49 to 51,362.
#
# The "...percent_enrolled" attributes are on a scale from 0 to 100 and represent the percentage of enrolled students among total students within the school, LEA/Charter, or the state.

# %% [markdown]
# #### Personnel data set
# The Personnel data set we examined has 3,096 rows of data, with 68 attributes. The data set contains observations from 2017. The data dictionary available for the data set is from 2014 and only contains descriptions for 55 of the attributes. The description for the 55 attributes can be found in the <a href="http://www.ncpublicschools.org/docs/src/researchers/data-dictionary.pdf">data dictionary</a> published by the NC Public Schools.
#
# As part of the data preparation process, we removed data from the personnel set related to grade schools and middle schools (i.e. category codes E, M, and I) because we are focused on the segment of the pipeline that leads from high school to enrollment in postsecondary education. We also removed 26 attributes that contained 84.7% or more missing values. Out of the 26 attributes, 15 attributes contained no values. All 15 attributes were data about highly qualified teachers.

# %% [markdown]
# | Column Name | Description | Type | % missing (in %) |
# |-------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------|-----------|
# | Year | School Year | Nominal | 0 |
# | Unit_code | Code to identify School/LEA/State | Nominal | 0 |
# | School_Name | School Name | Nominal | 15.4 |
# | Lea_Name | LEA Name | Nominal | .2 |
# | State_Name | State Name | Nominal | 0 |
# | Category_cd | Category code<br> <table><tr><td>E</td><td>School has elementary schools grades (PK-5)</td></tr> <tr><td>M</td><td>School has middle school grades (6-8)</td></tr> <tr><td>H</td><td>School has high school grades (9-13)</td></tr> <tr><td>I</td><td>School has elementary and middle school grades</td></tr> <tr><td>T</td><td>School has middle and high school grades</td></tr> <tr><td>A</td><td>School has elementary, middle, and high school grades</td></tr> </table> | Nominal | .1 |
# | St_Prin_advance_dgr_pct | Percent of principals with advanced degrees at state level | Ordinal | .1 |
# | St_1yr_prin_trnovr_pct | One year principal turnover rate at state level | Ordinal | .1 |
# | St_Prin_male_pct | Percent of male principals at state level | Ordinal | .1 |
# | St_prin_female_pct | Percent of female principals at state level | Ordinal | .1 |
# | St_Prin_black_pct | Percent of black principals at state level | Ordinal | .1 |
# | St_Prin_white_pct | Percent of white principals at state level | Ordinal | .1 |
# | Prin_other_pct | Percent of principals of other races including Indian, Asian, Hispanic and Pacific-islander at LEA level | Ordinal | 84.7 |
# | St_Prin_other_pct | Percent of principals of other races including Indian, Asian, Hispanic and Pacific-islander at state level | Ordinal | .1 |
# | Flicensed_teach_pct | Percent of teachers that meet NC fully licensed definition at school level | Ordinal | 15.5 |
# | Lea_flicensed_teach_pct | Average Percent of Teachers that meet NC fully licensed definition at LEA level | Ordinal | 6.7 |
# | St_flicensed_teach_pct | Average Percent of Teachers that meet NC fully licensed definition at state level | Ordinal | .1 |
# | Class_teach_num | Average number of classroom teachers at School Level | Continuous | 15.5 |
# | Lea_class_teach_num | Average number of classroom teachers at LEA Level | Continuous | 6.7 |
# | St_class_teach_num | Average number of classroom teachers at State Level | Continuous | .1 |
# | nbpts_num | Number of National Board Certified staff at LEA level | Continuous | 20.9 |
# | Lea_nbpts_num | Average number of National Board Certified staff at LEA level | Continuous | 6.7 |
# | St_nbpts_num | Average number of National Board Certified staff at state level | Continuous | .1 |
# | advance_dgr_pct | Percent of teachers with masters or higher degree at school level | Ordinal | 20.9 |
# | Lea_advance_dgr_pct | Average percent of teachers with masters or higher degree at LEA level | Ordinal | 209 |
# | St_advance_dgr_pct | Average percent of teachers with masters or higher degree at state level | Ordinal | .1 |
# | _1yr_tchr_trnovr_pct | One Year Teacher turnover percentage at school level | Ordinal | 21.6 |
# | Lea_1yr_tchr_trnovr_pct | One Year Teacher turnover percentage at LEA level | Ordinal | 209 |
# | St_1yr_tchr_trnovr_pct | One Year Teacher turnover percentage at state level | Ordinal | .1 |
# | Lateral_teach_pct | lateral entry teacher percentage at school level | Ordinal | 45.8 |
# | Lea_lateral_teach_pct | Average lateral entry teacher percentage at LEA level | Ordinal | 6.7 |
# | St_lateral_teach_pct | Average lateral entry teacher percentage at state level | Ordinal | .1 |
# | Total_class_teacher_num | Number of classroom teachers | Continuous | 0 |
# | Total_nbpts_num | Number of National Board Certified teachers | Continuous | 0 |

# %% [markdown]
# # Data Quality

# %% [markdown]
# In the college enrollment data set, we first removed all the records that summarized data for charter schools, the district, and state level. School level data includes enrollment percentages for both district and state level statistics already.
#
# Next, we examined the data set based on two key attributes: ENROLLED and ALL, which, when combined, created a subset of all the students that enrolled in postsecondary education. We limited this initial analysis to only this highest categorization of all students (rather than drilling down into gender, ethnicity, socio-economic status, etc.).

# %%
# %matplotlib inline
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True) # one of the many color mappings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from IPython.display import HTML, display

# %%
verboseStatus = False

# %%
# Brett's directory
# Desktop
#%cd "C:\Sandbox\SMU\dataMining\ChoRepo\EducationDataNC\2017\Raw Datasets"
# Laptop
# %cd "C:\sandbox\SMU\dataMining\choNotebook\EducationDataNC\2017\Raw Datasets"

# Ryan's directory
#%cd "C:\Users\Clovis\Documents\7331DataMining\EducationDataNC\2017\Raw Datasets"

# Cho's directory. Either uncomment the cd statement above or make your own cd.
#%cd "/Users/chostone/Documents/Data Mining/7331DataMining/EducationDataNC/2017/Raw Datasets"

# NW directorY 
#%cd "C:\Users\Nicole Wittlin\Documents\7331DataMining\EducationDataNC\2017\Raw Datasets"
dfCollege = pd.read_csv("college-enrollment.csv")
dfTeachers = pd.read_csv("personnel.csv")

print('********* Initial Values Before Cleaning *******************')
dfCollege.info(verbose = verboseStatus)
# Out:
# C:\sandbox\SMU\dataMining\choNotebook\EducationDataNC\2017\Raw Datasets
# ********* Initial Values Before Cleaning *******************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12827 entries, 0 to 12826
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# Code adapted from Dr. Jake Drew's python notebook
# - https://github.com/jakemdrew/EducationDataNC/tree/master/2017/School%20Datasets/Source%20Code

# %% [markdown]
# Despite having access to the ML dataset for all public schools, we opted to apply the code used to create the ML dataset to create a clean set of data limited to the college enrollment information and personnel files. We reduced the data down to only public schools (no charter schools). Duplicate information on district and state percentage information was removed as it was unnecessary. For the personnel data we limited the information to teachers for high school grades. Once the unnecessary columns and rows were removed, we merged the two datasets on unit_code (school id). A descrepancy was found in the personnel data which included unit_codes which were not in the college enrollment file. Since we had no information on these additional schools, they were excluded from our data.

# %%
# Global declaration to limit float values to 2 significant figures
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## Clean Teacher Dataset

# %%
# For this study we are interested in only looking at public schools
# Remove district and state rows as this is duplicate information
pattern = r'\D'
filterResult = dfTeachers['unit_code'].str.contains(pattern)
dfTeachers = dfTeachers[~filterResult]

#Review dataset contents after drops
print('*********After: Removing rows with charter/district/state codes.*******************')
dfTeachers.info(verbose = verboseStatus)
print("Rows deleted: {}".format(filterResult.sum()))
# Out:
# *********After: Removing rows with charter/district/state codes.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2450 entries, 2 to 3084
# Columns: 73 entries, year to st_prin_other_pct
# dtypes: float64(65), int64(3), object(5)
# memory usage: 1.4+ MB
# Rows deleted: 646

# %%
# Remove any teachers that don't teach high school
pattern = r'E|M|I'
filterResult = dfTeachers['category_cd'].str.contains(pattern, na = False)
dfTeachersHS = dfTeachers[~filterResult]

#Review dataset contents after drops
print('*********After: Removing rows for elementary and middle school teachers.*******************')
dfTeachersHS.info(verbose = verboseStatus)
print("Rows deleted: {}".format(filterResult.sum()))
# Out:
# *********After: Removing rows for elementary and middle school teachers.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 2 to 3083
# Columns: 73 entries, year to st_prin_other_pct
# dtypes: float64(65), int64(3), object(5)
# memory usage: 346.9+ KB
# Rows deleted: 1850

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = dfTeachersHS.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
dfTeachersHS = dfTeachersHS.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
dfTeachersHS.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(SingleValueCols)))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 2 to 3083
# Columns: 44 entries, unit_code to st_prin_other_pct
# dtypes: float64(40), object(4)
# memory usage: 210.9+ KB
# Columns deleted: 29

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = dfTeachersHS.shape[0]
NullValueCounts = dfTeachersHS.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
dfTeachersHS = dfTeachersHS.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
dfTeachersHS.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(NullValueCols)))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 2 to 3083
# Columns: 44 entries, unit_code to st_prin_other_pct
# dtypes: float64(40), object(4)
# memory usage: 210.9+ KB
# Columns deleted: 0

# %%
# Columns below are removed because they contain no information as described in Data Meaning section 
# or is aggregated at the district and state level and we are only concerned with the school level.
delCols = dfTeachersHS.filter(like = 'prin').columns
dfTeachersHS = dfTeachersHS.drop(columns = delCols, axis = 1)

#Review dataset contents after principle columns dropped
print('*********After: Removing columns with principle data.*************')
dfTeachersHS.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(delCols)))
# Out:
# *********After: Removing columns with principle data.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 2 to 3083
# Columns: 34 entries, unit_code to st_lateral_teach_pct
# dtypes: float64(30), object(4)
# memory usage: 164.1+ KB
# Columns deleted: 10

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
missingThreshold = .50
schoolDataRecordCt = dfTeachersHS.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = dfTeachersHS.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
dfTeachersHS = dfTeachersHS.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
dfTeachersHS.info(verbose = verboseStatus)
print("Columns Deleted: {}".format(len(NullValueCols)))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 2 to 3083
# Columns: 32 entries, unit_code to st_lateral_teach_pct
# dtypes: float64(28), object(4)
# memory usage: 154.7+ KB
# Columns Deleted: 2

# %% [markdown]
# ## Clean College Enrollment Dataset

# %%
# For this study we are interested in only looking at public schools
# Remove district and state rows as this is duplicate information
pattern = r'\D'
filterResult = dfCollege['unit_code'].str.contains(pattern)
dfCollege = dfCollege[~filterResult]

#Review dataset contents after drops
print('*********After: Removing rows with charter, district, and state codes.*******************')
dfCollege.info(verbose = verboseStatus)
print("Rows deleted: {}".format(filterResult.sum()))
# Out:
# *********After: Removing rows with charter, district, and state codes.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9863 entries, 0 to 12783
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.1+ MB
# Rows deleted: 2964

# %%
# Remove the demographic columns since we are only concerned with schools as a whole
pattern = r'ALL'
allStudents = dfCollege['subgroup'].str.contains(pattern)
dfCollegeDemographic = dfCollege[~allStudents]
dfCollegeAll = dfCollege[allStudents]

#Review dataset contents after drops
print('*********After: Removing rows without ALL status.*******************')
dfCollegeAll.info(verbose = verboseStatus)
print("Rows deleted: {}".format(len(dfCollegeDemographic)))
# Out:
# *********After: Removing rows without ALL status.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052 entries, 0 to 12768
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 115.1+ KB
# Rows deleted: 8811

# %%
# Remove the NOENROLL column since this is 1 - ENROLL column data
pattern = r'NOENROLL'
noEnrollRowCount = dfCollegeAll['status'].str.contains(pattern)
dfCollegeAll = dfCollegeAll[~noEnrollRowCount]

#Review dataset contents after drops
print('*********After: Removing rows with NOENROLL status.*******************')
dfCollegeAll.info(verbose = verboseStatus)
print("Rows deleted: {}".format(noEnrollRowCount.sum()))
# Out:
# *********After: Removing rows with NOENROLL status.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Rows deleted: 536

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = dfCollegeDemographic.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
dfCollegeDemographic = dfCollegeDemographic.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
dfCollegeAll.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(SingleValueCols)))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Columns deleted: 1

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = dfCollegeDemographic.shape[0]
UniqueValueCounts = dfCollegeDemographic.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
dfCollegeDemographic = dfCollegeDemographic.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
dfCollegeAll.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(AllUniqueValueCols)))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Columns deleted: 0

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = dfCollegeAll.shape[0]
NullValueCounts = dfCollegeAll.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
dfCollegeAll = dfCollegeAll.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
dfCollegeAll.info(verbose = verboseStatus)
print("Columns deleted: {}".format(len(NullValueCols)))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Columns deleted: 0

# %%
# Replace any missing district information with the mean district value
dfCollegeAll['lea_percent_enrolled'] = dfCollegeAll.groupby('leaname')['lea_percent_enrolled'].transform(lambda x: x.fillna(x.mean()))

#Review dataset contents after empty field drops
print('*********After: Replacing Missing District Percentages******')
dfCollegeAll.info(verbose = verboseStatus)
print("Missing Data: {}".format(dfCollegeAll.lea_percent_enrolled.isna().sum()))
# Out:
# *********After: Replacing Missing District Percentages******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Missing Data: 0

# %%
#Isolate continuous and categorical data types
#These are indexers into the dfCollege dataframe and may be used similar to the dfCollege dataframe 
sD_boolean = dfCollegeAll.loc[:, (dfCollegeAll.dtypes == bool) ]
sD_nominal = dfCollegeAll.loc[:, (dfCollegeAll.dtypes == object)]
sD_continuous = dfCollegeAll.loc[:, (dfCollegeAll.dtypes != bool) & (dfCollegeAll.dtypes != object)]
print("Boolean Columns: {}".format(sD_boolean.shape[1]))
print("Nominal Columns: {}".format(sD_nominal.shape[1]))
print("Continuous Columns: {}".format(sD_continuous.shape[1]))
print("Columns Accounted for: {}".format(sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]))
# Out:
# Boolean Columns: 0
# Nominal Columns: 6
# Continuous Columns: 7
# Columns Accounted for: 13

# %%
# One hot encoding for demographic information
dfCollegeDemographic = pd.get_dummies(dfCollegeDemographic, prefix = 'sub', columns = ['subgroup', 'subgroup_name'])

# %%
# Replace any missing district information with the mean district value
dfCollegeDemographic['lea_percent_enrolled'] = dfCollegeDemographic.groupby('leaname')['lea_percent_enrolled'].transform(lambda x: x.fillna(x.mean()))

#Review dataset contents after empty field drops
print('*********After: Remaining NaN rows******')
dfCollegeDemographic.info(verbose = verboseStatus)
print("Missing Data: {}".format(dfCollegeAll.lea_percent_enrolled.isna().sum()))
# Out:
# *********After: Remaining NaN rows******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8811 entries, 2 to 12783
# Columns: 34 entries, unit_code to sub_White
# dtypes: float64(6), object(4), uint8(24)
# memory usage: 963.7+ KB
# Missing Data: 0

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
missingThreshold = .60
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
dfCollegeAll = dfCollegeAll.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
dfCollegeAll.info(verbose = verboseStatus)
print("Columns Deleted: {}".format(len(NullValueCols)))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516 entries, 0 to 12767
# Columns: 13 entries, graduation_year to sea_percent_enrolled
# dtypes: float64(6), int64(1), object(6)
# memory usage: 56.4+ KB
# Columns Deleted: 0

# %% [markdown]
# ### <span style="color: red; background-color: yellow; font-size: 26px"> Simple Statistics</span>

# %%
dfCollegeAll.describe()
# Out:
#        graduation_year  schcount  leacount  seacount  sch_percent_enrolled  \
# count           516.00    489.00    516.00    516.00                516.00
# mean           2015.00    102.32   1131.87  51362.00                 49.69
# std               0.00     80.98   1480.69      0.00                 14.27
# min            2015.00      5.00     18.00  51362.00                  5.41
# 25%            2015.00     38.00    252.00  51362.00                 42.48
# 50%            2015.00     87.00    607.00  51362.00                 51.70
# 75%            2015.00    140.00   1178.00  51362.00                 59.01
# max            2015.00    423.00   5844.00  51362.00                 89.58
#
#        lea_percent_enrolled  sea_percent_enrolled
# count                516.00                516.00
# mean                  51.04                 51.99
# std                    6.88                  0.00
# min                   31.43                 51.99
# ...

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> NEW MATERIAL</span>

# %%
dfCollegeAll['schcount'].mode()
# Out:
# 0   20.00
# dtype: float64

# %%
dfCollegeAll['schname'].count()
# Out:
# 516

# %%
dfCollegeAll['schcount'].sum()
# Out:
# 50035.0

# %% [markdown]
# #### <span style="color: red">COLLEGE ENROLLMENT STATISTICS</span>
#
# <span style="color: red">For this analysis, we removed elementary and middle schools, as well as Charter and Non-Affiliated Schools. This resulted in a total of 516 individual public high schools for which we analyzed post-secondary enrollment.</span>
#
# <span style="color: red">For the schools in our data set, simple statistics include the following.</span>

# %% [markdown]
# | Statistic | Summary                                                                                                 |
# |-----------|---------------------------------------------------------------------------------------------------------|
# | Counts    | 50,035 students enrolled in post-secondary schooling                                                    |
# | Range     | At the individual school level between 5 and 423 students enrolled in post-secondary education          |
# | Mode      | Across all the school, the most frequent number of student enrolling in post-secondary education was 20 |
# | Median    | The median enrollment was 87 students                                                                   |
# | Mean      | On average, 102 students enrolled per school, but the variance here could be as much 81 students        |

# %% [markdown]
# <span style="color: red">For these same schools, the percentage of enrolled students is as follows:</span>

# %% [markdown]
# | Statistic | Summary                                                                                       |
# |-----------|-----------------------------------------------------------------------------------------------|
# | Counts    | 94.77% of the schools had students enroll in post-secondary schooling (calculation = 489/516) |
# | Range     | At the individual school level between 5.41% and 89.58% enrolled in post-secondary education  |
# | Median    | The median percent of enrollment was 51.70%                                                   |
# | Mean      | On average, 49.69% enrolled per school, but the variance here could be as much 14.27%         |

# %% [markdown]
# <span style="color: red">The most interesting finding from these statistics is that the enrollment percentage at the school level can vary so widely from just under 6% to nearly 90%. These are definitely outliers to examine further in our analysis to see if there are specific factors driving this disparity.</span>
#
# <span style="color: red">Overall, in the state of North Carolina in 2015, 51,362 students enrolled in post-secondary education, which represents 51.99% of the population at all state high schools. The National Center for Education Statistics (NCES) monitors similar statistics at the national level. According to latest release, the immediate college enrollment rate (i.e. the annual percentage of high school completers that enroll in 2- or 4- year colleges in the fall immediately following high school) was 63% in 2000 and 70% in 2016, making the national trend markedly higher than the trend in North Carolina. If the national data can be aggregated to the school, district, or state levels, this might be useful comparative information for developing new features or contextualizing post-secondary enrollment beyond one state.</span>
#
# <span style="color: red">Note: source of NCES analysis is the U.S. Department of Commerce, Census Bureau, Current Population Survey (CPS), October Supplement, 2000 through 2016. See Digest of Education Statistics 2017, table 302.10.</span>
#
# Citation: https://nces.ed.gov/programs/coe/indicator_cpa.asp

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %%
dfTeachersHS.describe()
# Out:
#        flicensed_teach_pct  tchyrs_0thru3_pct  tchyrs_4thru10_pct  \
# count               598.00             598.00              598.00
# mean                  0.89               0.21                0.24
# std                   0.10               0.12                0.10
# min                   0.30               0.00                0.00
# 25%                   0.85               0.13                0.19
# 50%                   0.92               0.20                0.23
# 75%                   0.96               0.26                0.29
# max                   1.00               0.83                0.86
#
#        tchyrs_11plus_pct  class_teach_num  nbpts_num  advance_dgr_pct  \
# count             598.00           598.00     598.00           598.00
# mean                0.55            48.30       6.22             0.27
# std                 0.14            35.81       6.63             0.13
# min                 0.08             2.00       0.00             0.00
# ...

# %%
dfMergedSet = pd.merge(dfTeachersHS, dfCollegeAll, on = 'unit_code')

# %%
dfMergedSet.drop(columns = ['year', 'graduation_year'], axis = 1, inplace = True, errors = 'ignore')

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> NEW MATERIAL</span>

# %%
dfMergedSet.describe()
# Out:
#        flicensed_teach_pct  tchyrs_0thru3_pct  tchyrs_4thru10_pct  \
# count               516.00             516.00              516.00
# mean                  0.89               0.21                0.24
# std                   0.10               0.12                0.09
# min                   0.30               0.00                0.00
# 25%                   0.86               0.14                0.19
# 50%                   0.92               0.20                0.24
# 75%                   0.96               0.26                0.29
# max                   1.00               0.83                0.62
#
#        tchyrs_11plus_pct  class_teach_num  nbpts_num  advance_dgr_pct  \
# count             516.00           516.00     516.00           516.00
# mean                0.55            52.76       6.85             0.26
# std                 0.13            35.72       6.78             0.11
# min                 0.08             2.00       0.00             0.00
# ...

# %% [markdown]
# #### <span style="color: red">PERSONNEL STATISTICS</span>
#
# <span style="color: red">Using the school and state level information about teacher experience, turnover, qualifications, and education, the tables below summarize key statistics about high school teachers at the school level as compared to the state level.</span>

# %% [markdown]
# | Summary Statistics | School Level | (sch) | (sch) | (sch) | (sch) | State Level | (st) | (st) | (st) | (st) |
# |---------------------------------------------|--------------|-------|-----|--------|-----|-------------|------|-----|--------|-----|
# | Statistics | Mean | Std | Min | Median | Max | Mean | Std | Min | Median | Max |
# | Average Number of Classroom Teachers | 52.76 | 35.72 | 2 | 51 | 159 | 50.71 | 7.49 | 24 | 53 | 53 |
# | Number of National Board-Certified Teachers | 6.85 | 6.78 | 0 | 5 | 38 | 6.53 | 1.45 | 2 | 7 | 7 |
# | % of Turnover Among 1-year Teachers | 15% | 9% | 0% | 14% | 50% | 26% | 2% | 26% | 26% | 31% |

# %% [markdown]
# #### <span style="color: red">Experience and Qualifications Summary</span>

# %% [markdown]
# | Summary Statistics | School Level | (sch) | (sch) | (sch) | (sch) | State Level | (st) | (st) | (st) | (st) |
# |-----------------------------------|--------------|-------|-------|--------|-------|-------------|------|------|--------|------|
# | Statistics | Mean | Std | Min | Median | Max | Mean | Std | Min | Median | Max |
# | % of Licensed Teachers | 0.89 | 0.10 | 0.30 | 0.92 | 1.00 | 0.89 | 0.02 | 0.78 | 0.90 | 0.90 |
# | Teacher % w/0-3 years experience | 0.21 | 0.12 | 0.00 | 0.20 | 0.83 | 0.21 | 0 | 0.20 | 0.21 | 0.21 |
# | Teacher % w/4-10 years experience | 0.24 | 0.09 | 0.00 | 0.24 | 0.62 | 0.24 | 0 | 0.24 | 0.24 | 0.25 |
# | Teacher % w/11+ years experience | 0.55 | 0.13 | 0.08 | 0.55 | 1.00 | 0.55 | 0 | 0.55 | 0.55 | 0.56 |
# | Teacher % w/Advanced Degrees | 0.26 | 0.11 | 0 | 0.25 | 0.75 | 0.26 | 0.02 | 0.26 | 0.26 | 0.31 |

# %% [markdown]
# <span style="color: red">Generally, these mirror what we would have expected to see. There may be a few outliers to explore related to schools that include: 100% of licensed teachers, 100% of teachers with 11+ years of experience, and 50% turnover among first year teachers.</span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %% [markdown]
# # <span style="color: red; background-color: yellow; font-size: 26px"> Visualize Attributes </span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> NEW MATERIAL</span>

# %%
binValues = np.arange(int(dfCollegeAll.lea_percent_enrolled.min()), int(dfCollegeAll.lea_percent_enrolled.max()), 3)
districtOut = pd.cut(dfCollegeAll.lea_percent_enrolled, bins = binValues, include_lowest = True)
count = districtOut.value_counts(sort=False)
ax = count.plot.barh(x = binValues, y = count).set(title = 'College Enrollment Percentage by Districts',
                                             xlabel = 'Number of Districts per Bin',
                                             ylabel = 'College Enrollment Percentage (%)')

# %% [markdown]
# <span style="color: red; background-color: white">This graph displays the postsecondary enrollment rate for public schools in NC. Due to the number of schoools, they were binned into groups seperated by 3%. We can see that the majority of schools within NC have a postsecondary enrollment rate around 50%. Further analysis will be necessary to understand why certain schools have an enrollment rate of greater than 60%. As well as why certain schools have an enrollment rate less than 40%.</span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %%
ordinalM = [col for col in dfMergedSet if '_pct' in col]
ax42 = dfMergedSet.hist(column = ordinalM, figsize = (14,14))
plt.title('Distribution of Normalized Teacher Attributes')
# Out:
# Text(0.5,1,'Distribution of Normalized Teacher Attributes')

# %% [markdown]
# Missing values removed from district calculations as these schools are Non-District schools and therefore do not have data on the district level

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> NEW MATERIAL</span>

# %%
ax = dfMergedSet.boxplot(column = ['sch_percent_enrolled', 'lea_percent_enrolled'], showmeans=True)
plt.title('Percentage of Students Enrolled in Postsecondary Education by School and District')
ax.set_ylabel('Percentage (%)')
ax.set_xlabel('Postsecondary Enrollment')
ax.xaxis.set_ticklabels(['By School', 'By District'])
# Out:
# [Text(0,0,'By School'), Text(0,0,'By District')]

# %% [markdown]
# <span style="color: red">As expected there is a large increase in variance in college enrollment rates at the individual school level compared to the district level. While this is the case, their medians and means are nearly identical.</span>

# %%
ax = dfMergedSet.boxplot(column = ['advance_dgr_pct', 'flicensed_teach_pct', 'tchyrs_0thru3_pct', 'tchyrs_4thru10_pct', 'tchyrs_11plus_pct', '_1yr_tchr_trnovr_pct'], figsize = (10, 8), showmeans=True)
plt.title('Boxplot of Teacher Attributes by School')
ax.set_xlabel('Teachers')
ax.set_ylabel('Percentage (%)')
ax.xaxis.set_ticklabels(['Graduate Degree', 'Licensed', '0-3 Years Exp', '4-10 Years Exp', '11+ Years Exp', '1 Year Turnover'])
# Out:
# [Text(0,0,'Graduate Degree'),
#  Text(0,0,'Licensed'),
#  Text(0,0,'0-3 Years Exp'),
#  Text(0,0,'4-10 Years Exp'),
#  Text(0,0,'11+ Years Exp'),
#  Text(0,0,'1 Year Turnover')]

# %% [markdown]
# <span style="color: red">A notable trend here is that a majority of teachers have more than 11 years experience. The median of percent teachers with 11+ years of experience at a school (56%) is more than double that of teachers with 0-3 (20%) or 4-10 (23%) years experience. This tells us that the median school will be more than half staffed with teachers with over 11 years of experience.
#
# <span style="color: red">Also of note is the high median percent of teachers that are licensed (92%). This is skewed heavily toward the lower percentages because of the max being 100% and a large amount of outliers of schools with their percent teachers that are licensed ranging from approximately 68% to as low as 30%. Further analsyis should noted if these school outliers have correlations to college enrollment and the experience level of these teachers.
#
# <span style="color: red">Lastly another dataframe will be created to examine the teacher attributes of the subset of outlier instances of the 1 year turnover rate of the teachers.

# %%
dfMergedSet_flicensed_lessthan_68percent = dfMergedSet[dfMergedSet.flicensed_teach_pct <= .68]
ax = dfMergedSet_flicensed_lessthan_68percent.boxplot(column = ['advance_dgr_pct', 'tchyrs_0thru3_pct', 'tchyrs_4thru10_pct', 'tchyrs_11plus_pct', '_1yr_tchr_trnovr_pct'], figsize = (10, 8), showmeans=True)
plt.title('Boxplot of Teacher Attributes per School with < 65% Licensed Teachers')
ax.set_xlabel('Teachers')
ax.set_ylabel('Percentage (%)')
ax.xaxis.set_ticklabels(['Graduate Degree', '0-3 Years Exp', '4-10 Years Exp', '11+ Years Exp', '1 Year Turnover'])
# Out:
# [Text(0,0,'Graduate Degree'),
#  Text(0,0,'0-3 Years Exp'),
#  Text(0,0,'4-10 Years Exp'),
#  Text(0,0,'11+ Years Exp'),
#  Text(0,0,'1 Year Turnover')]

# %% [markdown]
# <span style="color: red;">
# Medians:
#
# | Attributes   |      Overall      |  Outliers of low licensed teacher % |
# |----------|:-------------:|------:|
# | % Turnover |  14 | 28 |
# | % Grad Degree |    25   |   17 |
# | % 0-3 years Exp | 20 |    43 |
# |  % 4-10 years Exp        |    23           |   17    |
# |  % 11+ years Exp        |     56          |   37    |
#
# <span style="color: red">When looking at the distribution of teacher attributes when schools have less than 68% of their teacher's licensed we can see a dramatic increase in the median percent of teachers at those schools who have 0-3 years experience teaching. This median of percent teachers with 0-3 years experience, 43%, is now slightly more than teachers with 11+ years of experience, 37%. Also there is a doubling of the percentage of one year teacher turnover at these outlier schools.

# %%
dfMergedSet_1yrtrnovr_greaterthan_32percent = dfMergedSet[dfMergedSet._1yr_tchr_trnovr_pct >= .32]
ax = dfMergedSet_1yrtrnovr_greaterthan_32percent.boxplot(column = ['advance_dgr_pct', 'flicensed_teach_pct', 'tchyrs_0thru3_pct', 'tchyrs_4thru10_pct', 'tchyrs_11plus_pct'], figsize = (10, 8), showmeans=True)
plt.title('Boxplot of Teacher Attributes per School with > 32% 1st Yr Teacher Turnover')
ax.set_xlabel('Teachers')
ax.set_ylabel('Percentage (%)')
ax.xaxis.set_ticklabels(['Graduate Degree', 'Licensed', '0-3 Years Exp', '4-10 Years Exp', '11+ Years Exp'])
# Out:
# [Text(0,0,'Graduate Degree'),
#  Text(0,0,'Licensed'),
#  Text(0,0,'0-3 Years Exp'),
#  Text(0,0,'4-10 Years Exp'),
#  Text(0,0,'11+ Years Exp')]

# %% [markdown]
# <span style="color: red">
# Medians:
#
# | Attributes   |      Overall      |  Outliers of high turnover % |
# |----------|:-------------:|------:|
# | % Licensed |  92 | 72 |
# | % Grad Degree |    25   |   20 |
# | % 0-3 years Exp | 20 |    31 |
# |  % 4-10 years Exp        |    23           |   17    |
# |  % 11+ years Exp        |     56          |   40    |
#
# <span style="color: red">When comparing the subset of teachers attributes for when above 32% of a school's teachers turnover rate to the entire teacher data set we see a decrease in medians for percent teachers who are licensed, hold a graduate degree, have 4-10 years experience, and 11+ years of experience. There is a 11% increase in the median of percentage of teachers who have 0-3 years experience.

# %% [markdown]
# <span style="color: red">Medians:
#
# | Attributes   |      Overall      |  Outliers of high turnover % | Outliers of low licensed teacher %  |
# |----------|:-------------:|------:|---|
# | % Licensed |  92 | 72 | -  |
# | % Turnover |    14 |  - | 28  |
# | % Grad Degree | 25 |    20 | 17  |
# | % 0-3 years Exp  | 20 | 31 | 43  |
# | % 4-10 years Exp | 23 | 17 | 17  |
# | % 11+ years Exp  | 56 | 40 | 37  |

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %% [markdown]
# # Explore Joint Attributes

# %%
corrColumnNames = ['flicensed_teach_pct',
 'tchyrs_0thru3_pct',
 'tchyrs_4thru10_pct',
 'tchyrs_11plus_pct',
 'class_teach_num',
 'nbpts_num',
 'advance_dgr_pct',
 'sch_percent_enrolled',
 'lea_percent_enrolled']

dfCorr = dfMergedSet[corrColumnNames].corr('pearson')

# %%
#scatter plot matrix of all attributes
ax = scatter_matrix(dfMergedSet[corrColumnNames], figsize = (14, 14))
#rotate labels
[s.xaxis.label.set_rotation(45) for s in ax.reshape(-1)]
[s.yaxis.label.set_rotation(65) for s in ax.reshape(-1)]
#hide tick marks
[s.set_xticks(()) for s in ax.reshape(-1)]
[s.set_yticks(()) for s in ax.reshape(-1)]
plt.title('Scatter Plot Matrix of Teacher Attributes and College Enrollment Percentages')
# Out:
# Text(0.5,1,'Scatter Plot Matrix of Teacher Attributes and College Enrollment Percentages')

# %% [markdown]
# A key take away from the histograms shown are that the attributes are mostly normally distributed.
#
# Execeptions are of the percentage of teachers who are licensed at a school, which is highly left skewed due to many schools hiring teachers who have their teaching license. Another exception is the percentage of teachers with little experience (0-3 years) per school being right skewed, showing that schools have a majority of staff that exceed this experience threshold. Another right skewed distribution is seen for the number of National Board Certified Staff at the school level (nbpts_num). Since this is not normalized and simply a count per school, this is a major reason why it is right skewed. As seen in the scatter plot, this highly correlates with the average number of classroom teachers at the school level (class_teach_num) because clearly as the average number of teachers at a school increases, the likelihood of the staff count being board certified will increase as well.
#
# Most of the scatterplots show a near random cloud distribution or a normal distribution between two attributes. The most evident of negative correlations are seen in the comparison of the different experience levels. As the percentage of one of the experience levels increase at a school, by default the others must decrease.

# %%
# plot the correlation matrix using seaborn
sns.set(style="darkgrid") # one of the many styles to plot using

f, ax = plt.subplots(figsize=(14, 14))

sns.heatmap(dfMergedSet[corrColumnNames].corr(), cmap=cmap, annot=True)

f.tight_layout()

# %% [markdown]
# The correlation heatmap helps visualize linear relationships easier by color coding a matrix. The most notable positive linear relationships between our response variable (percent of students enrolled in college by school) and any explanatory variables of our teachers experience is the percentage of licensed teachers at a school (r = 0.22), the number of board certified teachers at school (r = 0.19), the percent of teachers with 11+ years of experience teaching (r = 0.15), and the percent of teachers with graduate degrees or more (r = 0.14). Although qualities of a teachers are sometimes hard to measure, the ones that are in the form of experience and accolades (licensure, board certified, and graduate degrees) show a weak linear relationship with the percentage of high school students who enroll in college.
#
# The strongest linear correlation of the heatmap with normalized data can be found with the percent of teachers with 11+ years of experience teaching and the percentage of licensed teachers (r = 0.46). This would make sense that as you continue along in your career in teaching, your likelihood of acquiring your license would be more likely. A similar linear correlation coefficient of 0.35 can be found between percent of teachers with graduate degrees and the percent of licensed teachers. Lastly, the percent of teachers with graduate degrees and percent of teachers with 11+ years of experience has a linear correlation coefficient of 0.32. All of this ties into the idea of associations with teachers who have had long careers in education have achieved high accolades in doing so.

# %%
# https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(dfCorr, 10))
# Out:
# Top Absolute Correlations
# flicensed_teach_pct   tchyrs_0thru3_pct      0.92
# class_teach_num       nbpts_num              0.86
# tchyrs_0thru3_pct     tchyrs_11plus_pct      0.82
# flicensed_teach_pct   tchyrs_11plus_pct      0.77
# tchyrs_0thru3_pct     advance_dgr_pct        0.64
# flicensed_teach_pct   advance_dgr_pct        0.60
# sch_percent_enrolled  lea_percent_enrolled   0.59
# tchyrs_11plus_pct     advance_dgr_pct        0.57
# tchyrs_4thru10_pct    tchyrs_11plus_pct      0.44
# tchyrs_11plus_pct     nbpts_num              0.37
# dtype: float64

# %%
ax = dfMergedSet.plot.scatter(x='class_teach_num', y='nbpts_num') \
 .set(title='Board Certified Teachers vs Average Number of Classroom Teachers',
      xlabel='Average Number of Classroom Teachers per School',
      ylabel='Board Certified Teachers per School')

# %% [markdown]
# When plotting the average number of classroom teachers at the school level versus the number of National Board Certified Staff at the school level, there is a strong positive correlation. As the average number of classroom teachers at the school level increases, so does the number of National Board Certified Staff. This is likely a clear example of correlation does not mean causation. The more teachers there are at a school, the likelihood of a raw count of National Board Certified Staff will increase.

# %%
ax = dfMergedSet.plot.scatter(x='tchyrs_0thru3_pct', y='tchyrs_11plus_pct') \
     .set(title='Teacher Experience: Less than 3 vs 11 or More Years',
         xlabel='3 Years or Less Experience per School',
         ylabel='11 or More Years Experience per School')

# %% [markdown]
# When plotting the percent experience of the teachers at a school there is obviously a negative correlation when you plot two ranges against one another. As the ratio of teachers who have 11+ years at a particular school increases, the rest of the experience ranges (0-3 years in this case) must decrease if the amount of teachers at the school stays constant. The inverse would be true as well.

# %%
ax = dfMergedSet.plot.scatter(x='flicensed_teach_pct', y='tchyrs_0thru3_pct') \
     .set(title='NC Fully Licensed Teachers vs 3 Years or Less of Experience',
         xlabel='Teachers NC Fully Licensed per School',
         ylabel='3 Years or Less of Experience per School')

# %% [markdown]
# When plotting the percent of teachers with entry level experience (0-3 years) versus the percent of teachers who are licensed at a school, there is an evident negative linear correlation. As the percent of teachers who are licensed at a school increases, the percent of teachers with entry level experience decreases.

# %%
ax = dfMergedSet.plot.scatter(x='flicensed_teach_pct', y='tchyrs_11plus_pct') \
    .set(title='NC Fully Licensed Teachers vs 11 or More Years of Experience',
         xlabel='Teachers NC Fully Licensed per School',
         ylabel='11 or More Years Experience per School')

# %% [markdown]
# When plotting the percent of teachers with 11+ years of experience versus the percent of teachers who are licensed at a school, there is an evident positive linear correlation. As the percent of teachers who are licensed at a school increases as does the percent of teachers with 11+ years of experience.

# %%
ax = dfMergedSet.plot.scatter(x='tchyrs_4thru10_pct', y='tchyrs_11plus_pct') \
     .set(title='4 to 10 Years vs 11 or More Years of Experience',
         xlabel='4 to 10 Years Experience per School',
         ylabel='11 or More Years Experience per School')

# %% [markdown]
# When plotting the percent experience of the teachers at a school, there is obviously a negative correlation when you plot two ranges against one another. As the ratio of teachers who have 11+ years at a particular school increases, the rest of the experience ranges (4-10 years in this case) must decrease if the amount of teachers at the school stays constant. The inverse would be true as well.

# %% [markdown]
# # <span style="color: red; background-color: yellow; font-size: 26px"> Explore Attributes and Class </span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px">NEW MATERIAL</span>
#
# <span style="color: red">We believe we can predict whether or not a school has greater than 35% of high school graduates enrolled in a post-secondary institution based on the following features: percentage of teachers that have advanced degrees (advance_dgr_pct), percentage of teachers that are licenced to teach (Flicensed_teach_pct), and the average number of teachers at a given school (Class_teach_num).</span>

# %%
dfMergedSet["meet_enrollment_pct"] = dfMergedSet['sch_percent_enrolled'].apply(lambda x: 1 if x > 51 else 0)

# %%
### CREATE NEW SCATTER PLOTS PLOTTING % ENROLLED IN POST-SECONDARY AND EACH FEATURE LISTED ABOVE
### % STUDENTS IN POST-SECONDARY VS ADVANCED DEGREES
(dfMergedSet
 .plot
 .scatter(x='advance_dgr_pct', y='sch_percent_enrolled')
 .set(title='Percentage of Teachers with Advanced Degrees vs. % of students enrolled post high school',
      xlabel='Teachers in % (0.0 to 1)',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'Teachers in % (0.0 to 1)'),
#  Text(0.5,1,'Percentage of Teachers with Advanced Degrees vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">There appears to be no correlation between teachers with advanced degrees and the percentage of students enrolled in a post-secondary institution since the scatter plot resembles a random cloud.

# %%
### % STUDENTS IN POST-SECONDARY VS Flicensed_teach_pct
(dfMergedSet
 .plot
 .scatter(x='flicensed_teach_pct', y='sch_percent_enrolled')
 .set(title='Percentage of Licensed Teachers vs. % of students enrolled post high school',
      xlabel='Teachers in % (0.0 to 1)',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'Teachers in % (0.0 to 1)'),
#  Text(0.5,1,'Percentage of Licensed Teachers vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">The majority of schools have over 50% of licensed teachers. There appears to be a weak positive correlation between the percentage of licensed teachers and the percentage of students enrolled in a post-secondary institution after graduating high school.

# %%
### % Students enrolled in post-secondary VS Class_teach_num
(dfMergedSet
 .plot
 .scatter(x='class_teach_num', y='sch_percent_enrolled')
 .set(title='Average number of teachers per school vs. % of students enrolled post high school',
      xlabel='Number of Teachers',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'Number of Teachers'),
#  Text(0.5,1,'Average number of teachers per school vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color:red">When plotting average number of teachers per year versus the percent of students who enroll in college at those schools you see a very weak linear correlation. However when percent students enrolled is plotted as the x, the average number of teachers per school looks similar to a normal distribution.

# %%
(dfMergedSet
 .plot
 .scatter(x='nbpts_num', y='sch_percent_enrolled')
 .set(title='Number of National Board Certified Staff at school level vs. % of students enrolled post high school',
      xlabel='Number of NBCS at School',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'Number of NBCS at School'),
#  Text(0.5,1,'Number of National Board Certified Staff at school level vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">To look to see if at a school level if the increase in the number of National Board Certified Staff would effect the percent college enrollment of the students we plotted the two against each other. The scatter plot shows there is virtually no correlation between the number of certified staff at the school and percentage of students who enrolled in college.

# %%
(dfMergedSet
 .plot
 .scatter(x='_1yr_tchr_trnovr_pct', y='sch_percent_enrolled')
 .set(title='One year teacher turnover percentage at school level vs. % of students enrolled post high school',
      xlabel='% One year teacher turnover',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'% One year teacher turnover'),
#  Text(0.5,1,'One year teacher turnover percentage at school level vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">To look to see if at a school level if the increase in the percent of teacher turnover per year would effect the percent college enrollment of the students we plotted the two against each other. There looks to be no correlation between the two due to the random distribution. However, when narrowing the scope of instances where the percent teacher turnover in that year was over 40%, 4 out of 6 instances the percent student college enrollment was below 20%. This is more than two standard deviations away from the mean and median college enrollment percentage.</span>

# %%
(dfMergedSet
 .plot
 .scatter(x='tchyrs_11plus_pct', y='sch_percent_enrolled')
 .set(title='% Teachers with 11+ years experience vs. % of students enrolled post high school',
      xlabel='% Teachers w/11+ years experience',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'% Teachers w/11+ years experience'),
#  Text(0.5,1,'% Teachers with 11+ years experience vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">It is very evident that there is no correlation between the percentage of students who enrolled in college and the percentage of teachers with 11+ years experience at the school.

# %%
(dfMergedSet
 .plot
 .scatter(x='tchyrs_0thru3_pct', y='sch_percent_enrolled')
 .set(title='% Teachers with 0-3 years experience vs. % of students enrolled post high school',
      xlabel='% Teachers w/0-3 years experience',
      ylabel='Students in % (0-100)'))
# Out:
# [Text(0,0.5,'Students in % (0-100)'),
#  Text(0.5,0,'% Teachers w/0-3 years experience'),
#  Text(0.5,1,'% Teachers with 0-3 years experience vs. % of students enrolled post high school')]

# %% [markdown]
# <span style="color: red">It is very evident that there is no correlation between the percentage of students who enrolled in college and the percentage of teachers with 0-3 years experience at the school. It looks nearly identical to the plot above with 11+ years of experience for the teachers except for its shift to the left due to their being a smaller percentage of teachers with 0-3 years of experience.

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

# Code adapted from https://stackoverflow.com/questions/23232989/boxplot-stratified-by-column-in-python-pandas
breaks = np.asarray(np.percentile(dfMergedSet['sch_percent_enrolled'], [25,50,75,100]))
dfMergedSet['Quartiles of % College Enrolled'] = (dfMergedSet['sch_percent_enrolled'].values > breaks[..., np.newaxis]).sum(0)
ax = dfMergedSet.boxplot(column='flicensed_teach_pct', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('% Licensed Teachers per School')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. There is a clear trend in increasing median percentage of licensed teachers as the quartiles of the percent of students at those schools enrolled in college after graduation. The difference between the lowest and highest quartile is about an eight percent increase in teachers who were licensed. Interestingly, the variability decreases for the quartiles as they increase except for the highest quartile which has more variability than the second quartile even though its median is still higher.</span>

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

ax = dfMergedSet.boxplot(column='class_teach_num', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('Average number of teachers per School')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. As the quartiles incrase for the percentage of students who enrolled in college the mean and median of the average number of teachers increased up until the 75-100% quartile. A hypothesis to this trend might be because the upper 75-100% quartile has smaller school sizes thus lowering the average number of teachers needed to teach the student body. This cannot be confirmed though as we do not have the class body size for the schools.

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

ax = dfMergedSet.boxplot(column='tchyrs_11plus_pct', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('% Teachers with 11+ Years Experience per School')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. While the median percentage of teachers who have 11+ years of experience increases from the lower quartile (0-25%) of schools who have the lowest percent of students who enroll in college, the median stays very constant in the other three quartiles. A similar trend is apparent for a decrease in variance after the lower quartile but says relatively constant for the other three quartiles.

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

ax = dfMergedSet.boxplot(column='tchyrs_0thru3_pct', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('% Teachers with 0-3 Years Experience per School')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. Although there is a decrease in the median % of teachers with 0-3 experience as the quartiles increase for the % of students who enrolled in college per school, it is very small. Of note though is the decreaseing variance as the quartiles increase. This shows that the median school will have a consistent amount of newer teachers to the profession (0-3 years experience) no matter the quartile of percent students who enrolled in college, once it increases beyond that median it is more likely that school will have a lower percent of students who enroll in college.

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

ax = dfMergedSet.boxplot(column='nbpts_num', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('Number of National Board Certified Staff at school level')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. Since these are raw counts and not normalized the data can be easily misinterpretted due to a school just being very large relative to another. So while their raw count of National Board Certified Staff might be larger than a smaller school their percentage of staff that is certified might be lower. This would effect its relationship with the percent of college enrolled students. With that being said you can see a clear trend that as the quartiles of percent college enrolled students increase, as does the number of certified staff at that school. Interestlingly though the 75-100% quartile does not follow this trend and has a median and average comparable to the 25-50% quartile. Also the variablility of the number of certified staff increases at an approximately linear rate as the quartile of percent college enrolled students increases.

# %%
########################################################################################################
############################### NEW PLOT ###############################################################
########################################################################################################

ax = dfMergedSet.boxplot(column='_1yr_tchr_trnovr_pct', by='Quartiles of % College Enrolled', showmeans=True)
ax.xaxis.set_ticklabels(['0-25%', '25-50%', '50-75%', '75-100%'])
ax.set_xlabel('Quartiles of % College Enrolled')
ax.set_ylabel('% Teacher Turnover in One Year per School')
ax.set_title('')
# Out:
# Text(0.5,1,'')

# %% [markdown]
# <span style="color: red">To look for differences in distributions of teacher attributes on the percentage of students who enrolled in college we broke this metric into quartiles. Although small, the median and mean percent teacher turnover in one year decreases as the quartiles of percent college enrolled increases. The same trend holds true for the variance as well with a slight exception for the 75-100% quartile's variance having more outliers and variance than the 50-75% quartile.
#
#
#
# <span style="color: red">All of these quartile plots of the percentage of students who enrolled in college exhibit behaviour one might expect from the attribute but at a small level. This might be because while each individual attribute is not all that important, the cumulative effect of them at a school is.
#
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %% [markdown]
# # <span style="color: red; background-color: yellow; font-size: 26px"> New Features </span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> NEW MATERIAL</span>

# %% [markdown]
# <span style="color: red; background-color: white; font-size: 14px">
# After further inspection of the attributes that we have available through the college enrollment and personnel datasets, there don't appear to be any clear indicators of why a school performs better than others. In order to get a more holistic point of view we will need to include all the data provided and found in the ML dataset. This includes student test scores in multiple areas, personnel performance, and more granular information on demographics within the school. By not limiting ourselves to the datasets we originally selected and accounting for any highly correlated attributes, we can allow the machine learning algorithms to have a much broader and richer set of attributes to feed into the model that should allow for better classification results.
# </span>
# <br>
# <br>
# <span style="color: red; background-color: white; font-size: 14px">
# In addition, we could include the national statistics for postsecondary enrollment from https://nces.ed.gov/programs/coe/indicator_cpa.asp. While this information may not help us build a better model, it does allow for the comparison of statistics across the US. It is possible that in some areas, possibly demographics, we can use the aggregated data to adjust the values we use for any missing information and could improve our results.
# </span>

# %% [markdown]
# <span style="color: red; background-color: yellow; font-size: 20px"> END NEW MATERIAL</span>

# %% [markdown]
# # Exceptional Work

# %% [markdown]
# Our team initially started out exploring another data set from Kaggle – Data Science for Social Good: Kiva Crowdfunding. The Kaggle competition asked participants to build localized models to estimate poverty levels where Kiva is providing microloans. After initial exploratory analysis, we found that the data set was not robust enough to support building models due to a lack of clear response variables. Thus, we decided to change to the North Carolina Educational Attainment data. Much of work this week was focused on understanding and connecting the College Enrollment and Personnel data sets. We have additional work to do on the analysis of the resulting joint data.
